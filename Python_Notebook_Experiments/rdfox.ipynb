# %% [markdown]
# These are experiments for the RDF Oxford Knowledge Graphs

# %%
! wget https://rdfox-distribution.s3.eu-west-2.amazonaws.com/release/v7.5/RDFox-linux-x86_64-7.5.zip
! unzip "RDFox-linux-x86_64-7.5.zip" && rm "RDFox-linux-x86_64-7.5.zip" 
! mv "RDFox-linux-x86_64-7.5" "RDFOX_KG"
# Out:
# --2025-12-17 05:45:53--  https://rdfox-distribution.s3.eu-west-2.amazonaws.com/release/v7.5/RDFox-linux-x86_64-7.5.zip
# Resolving rdfox-distribution.s3.eu-west-2.amazonaws.com (rdfox-distribution.s3.eu-west-2.amazonaws.com)... 52.95.142.26, 3.5.244.35, 3.5.246.85, ...
# Connecting to rdfox-distribution.s3.eu-west-2.amazonaws.com (rdfox-distribution.s3.eu-west-2.amazonaws.com)|52.95.142.26|:443... connected.
# HTTP request sent, awaiting response...
# 200 OK
# Length: 111890192 (107M) [application/zip]
# Saving to: ‘RDFox-linux-x86_64-7.5.zip’
#
# RDFox-linux-x86_64- 100%[===================>] 106.71M  33.8MB/s    in 3.2s
#
# 2025-12-17 05:45:57 (33.8 MB/s) - ‘RDFox-linux-x86_64-7.5.zip’ saved [111890192/111890192]
#
# Archive:  RDFox-linux-x86_64-7.5.zip
#    creating: RDFox-linux-x86_64-7.5/
#    creating: RDFox-linux-x86_64-7.5/examples/
#    creating: RDFox-linux-x86_64-7.5/examples/C/
#    creating: RDFox-linux-x86_64-7.5/examples/C++/
# ...
